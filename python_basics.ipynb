# %%
print("Hello World!")
# Out:
# Hello World!

# %%
age=10
print("My age is:",age)
print(type(age))
# Out:
# My age is: 10
# <class 'int'>

# %%
log = "ERROR,2025-01-15,SERVER-03,CPU_OVERLOAD"
types,date,task,reason=log.split(",")
print(f"{types} {date} {task} {reason}")
# Out:
# ERROR 2025-01-15 SERVER-03 CPU_OVERLOAD

# %%
raw_data = "   USER:2025-jupyter-77 | STATUS:active   "
clean_data = raw_data.strip().upper()
sections = clean_data.split("|")
user_id = sections[0].split(":")[1]
status = sections[1].split(":")[1]
year = user_id[:4]
if status == "ACTIVE" and year == "2025":
    print(f"User {user_id} authorized")
else:
    print("Access denied")
# Out:
# User 2025-JUPYTER-77  authorized

# %%
raw_data = "   USER:2025-jupyter-77 | STATUS:active   "
clean_data = raw_data.strip().upper()
sections = clean_data.split("|")
sections
# Out:
# ['USER:2025-JUPYTER-77 ', ' STATUS:ACTIVE']

# %%
num1="5"
num2=3
result=num1*num2
print(result)
# Out:
# 555

# %%
print((4+5)*5**(4-2))
# Out:
# 225

# %%
10>5 and 5<3
# Out:
# False

# %%
#ATM Machine
pin_number="1234"
count=0
while count<3:
    pin=input("Enter pin number:")
    if pin==pin_number:
        print("Access Granted")
        break
    count+=1   
else:
    print("Wrong Pin")
# Out:
# Access Granted

# %%
#Palindrome
word=input("Enter a word:")
if word[::-1]==word:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
sen=input("Enter a sentence:")
word=sen.split()
print(word)
print(len(word))
# Out:
# ['Bangladesh', 'is', 'my', 'country']
# 4

# %%
user=input("A sentence:")
print(len(user))
# Out:
# 17

# %%
user2=input("A sentence:").strip()
user2=user2.count(' ')+1
print(user2)
# Out:
# 4

# %%
word1 = "Python"
n=len(word1)
print(f"The number of character in the word \"{word1}\" is {n}.")
# Out:
# The number of character in the word "Python" is 6.

# %%
my_list=["apple","Banana","Mango","Watermelon","Guava","Jackfruit"]
while my_list:
    my_list.pop()
print(my_list)
# Out:
# []

# %%
my_list=["apple","Banana","Mango","Watermelon","Guava","Jackfruit"]

my_list.clear()

print(my_list)
# Out:
# []

# %%
user1=input("Enter something:").split(',')
drone=[]
for i in user1:
    drone.append(i)
print(drone)
# Out:
# ['Helicopter', 'UAV']

# %%
nums = [1, 2, 3]
nums.append(4)
print(nums)
print(len(nums))
# Out:
# [1, 2, 3, 4]
# 4

# %%
num=list(range(0,11))
num1=[i**2 if i%2==0 else i for i in num ]
print(num1)
# Out:
# [0, 1, 4, 3, 16, 5, 36, 7, 64, 9, 100]

# %%
# sending mail to subscriber
mail_list=['user1@gmail.com','user2@gmail.com','user3@gmail.com','user4@gmail.com','user5@gmail.com']
mail=[i for i in mail_list if i !='user3@gmail.com']
print(mail)
# Out:
# ['user1@gmail.com', 'user2@gmail.com', 'user4@gmail.com', 'user5@gmail.com']

# %%
name = "John"

age = 25

print(f"My name is {name} and I am {age} years old")
# Out:
# My name is John and I am 25 years old

# %%
import math

print(math.sqrt(16))
# Out:
# 4.0
