# %%
#tuple
t = (10, 3.14, "hello", "world",[10,3.14])
a,*c = t
print(t)
print("a=",a)
print("c=",c)
t.count("hello")
# Out:
# (10, 3.14, 'hello', 'world', [10, 3.14])
# a= 10
# c= [3.14, 'hello', 'world', [10, 3.14]]
# 1

# %%
print(t[-5:-4:-1])
# Out:
# ()

# %%
#set
s = {1, 2, 3}

s.remove(2)    
#s.remove(4)    
s.discard(4)   
print(s)
# Out:
# {1, 3}

# %%
# update a item in a dictionary

d = {"name": "Soumit", "age": 20, "work": "UAP"}
print(d)

d["age"] =  26
print(d)

d.update({"age": 30})
print(d)

d.update({"city": "Dhaka"})
print(d)
# Out:
# {'name': 'Soumit', 'age': 20, 'work': 'UAP'}
# {'name': 'Soumit', 'age': 26, 'work': 'UAP'}
# {'name': 'Soumit', 'age': 30, 'work': 'UAP'}
# {'name': 'Soumit', 'age': 30, 'work': 'UAP', 'city': 'Dhaka'}

# %% [markdown]
# # Practice Dictionary

# %%
employee_db={
    "Alex":{
    "projects":["Robotics project","Website","DataBase"],
    "skills":{"Python","C","Robotics","Java","Machine Learning"},
    "info":("age:25","blood_group:A+")
    },
    "Stephen":{
    "projects":["Frontend","IoT","software"],
    "skills":{"Laravel","C++","Robotics","Java","Deep Learning"},
    "info":("age:30","blood_group:O+") 
    }
}

# %%
employee_db["Stephen"]
# Out:
# {'projects': ['Frontend', 'IoT', 'software'],
#  'skills': {'C++', 'Deep Learning', 'Java', 'Laravel', 'Robotics'},
#  'info': ('age:30', 'blood_group:O+')}

# %%
employee_db["Alex"]["projects"][0]
# Out:
# 'Robotics project'

# %%
employee_db.items()
# Out:
# dict_items([('Alex', {'projects': ['Robotics project', 'Website', 'DataBase'], 'skills': {'Robotics', 'Machine Learning', 'C', 'Python', 'Java'}, 'info': ('age:25', 'blood_group:A+')}), ('Stephen', {'projects': ['Frontend', 'IoT', 'software'], 'skills': {'Robotics', 'Deep Learning', 'C++', 'Laravel', 'Java'}, 'info': ('age:30', 'blood_group:O+')})])

# %%
employee_db.get("Hasan","Not found")
# Out:
# 'Not found'

# %%
stephen_info=employee_db.get("Stephen")

# %%
stephen_info.update({"career":"none"})

# %%
stephen_info
# Out:
# {'projects': ['Frontend', 'IoT', 'software'],
#  'skills': {'C++', 'Deep Learning', 'Java', 'Laravel', 'Robotics'},
#  'info': ('age:30', 'blood_group:O+'),
#  'career': 'none'}

# %%
employee_db
# Out:
# {'Alex': {'projects': ['Robotics project', 'Website', 'DataBase'],
#   'skills': {'C', 'Java', 'Machine Learning', 'Python', 'Robotics'},
#   'info': ('age:25', 'blood_group:A+')},
#  'Stephen': {'projects': ['Frontend', 'IoT', 'software'],
#   'skills': {'C++', 'Deep Learning', 'Java', 'Laravel', 'Robotics'},
#   'info': ('age:30', 'blood_group:O+'),
#   'career': 'none'}}

# %%
stephen_info["projects"].append("Arduino Projects")

# %%
stephen_info
# Out:
# {'projects': ['Frontend', 'IoT', 'software', 'Arduino Projects'],
#  'skills': {'C++', 'Deep Learning', 'Java', 'Laravel', 'Robotics'},
#  'info': ('age:30', 'blood_group:O+'),
#  'career': 'none'}

# %%
user_list = ["alvi@mail.com", "sadia@gmail.com", "abir@yahoo.com"]

for user_id in range(len(user_list)): # access index
    print(user_id)
# Out:
# 0
# 1
# 2

# %%
user_list = ["alvi@mail.com", "sadia@gmail.com", "abir@yahoo.com"]

for user_id in range(len(user_list)): # len(user_list) = 3 range(3) = 0, 1, 2
    print(user_id+1, user_list[user_id])  # basically index
# Out:
# 1 alvi@mail.com
# 2 sadia@gmail.com
# 3 abir@yahoo.com

# %%
fruits = ["Apple", "Banana", "Mango"]

for idx, value in enumerate(fruits,start=1):
    print(idx, value)
# Out:
# 1 Apple
# 2 Banana
# 3 Mango

# %%
#map
price_list = {"Rice": 60, "Salt": 30, "Sugar": 100}

discount_price_list = {}

for item, price in price_list.items():
    discount_price_list[item] = price*0.9

print(discount_price_list)
# Out:
# {'Rice': 54.0, 'Salt': 27.0, 'Sugar': 90.0}

# %%
#map
#Dictionary comprehension
price_list = {"Rice": 60, "Salt": 30, "Sugar": 100}
discount_price_list = {item:price*0.9 for item, price in price_list.items()}
print(discount_price_list)
# Out:
# {'Rice': 54.0, 'Salt': 27.0, 'Sugar': 90.0}

# %%
# filter

product_list = {"Bread": False, "Milk": True, "Juice": False, "Buiscuits": True}  # True -> Date over

new_product_list = {}

for product, is_date_over in product_list.items():
    if not is_date_over: #filter
        new_product_list[product] = is_date_over

new_product_list
# Out:
# {'Bread': False, 'Juice': False}

# %%
#filter
product_list = {"Bread": False, "Milk": True, "Juice": False, "Buiscuits": True}  # True -> Date over
new_product_list = {product:is_date_over for product, is_date_over in product_list.items() if not is_date_over}
print(new_product_list)
# Out:
# {'Bread': False, 'Juice': False}

# %%
#map+filter
results={'Alvi':80,'Alex':75,'David':68,'Lisa':95,'Paulson':60}

final_results={}
for name,mark in results.items():
    if mark>70: #filter
        final_results[name]=(mark,'congrats') #map
        
print(final_results)
# Out:
# {'Alvi': (80, 'congrats'), 'Alex': (75, 'congrats'), 'Lisa': (95, 'congrats')}

# %% [markdown]
# # Small Project

# %%
## website - hide senstive informations (e.g. phone number) for underage users

users = {
    "Alvi": {"city": "Dhaka",  "age": 17, "phone": 217457},
    "Sadia": {"city": "New York", "age": 22, "phone": 12763},
    "Samia": {"city": "Rajshahi", "age": 14, "phone": 169463},
    "Jahid": {"city": "London", "age": 20, "phone": 76435},
    "Hasan": {"city": "Istambl", "age": 23, "phone": 76435},
}

for name, info in users.items():
    # showing names
    print("Name:", name, end = " | ")

    ## showing informations
    if info["age"] >= 18:
        # show all informations
        for info_key, info_value in info.items():
            print(f"{info_key}: {info_value}", end = " | ")
    else:
        # show information without phone
        for info_key, info_value in info.items():
            if not info_key == "phone":
                print(f"{info_key}: {info_value}", end = " | ")

    print()
# Out:
# Name: Alvi | city: Dhaka | age: 17 |
# Name: Sadia | city: New York | age: 22 | phone: 12763 |
# Name: Samia | city: Rajshahi | age: 14 |
# Name: Jahid | city: London | age: 20 | phone: 76435 |
# Name: Hasan | city: Istambl | age: 23 | phone: 76435 |

# %% [markdown]
# # More Problem

# %%
user_id = ["001", "002", "003", "004", "005"]   # 5
user_names = ["Alvi", "Sadia", "Abir", "Jahid"] # 4
user_mails = ["alvi@mail.com", "sadia@gmail.com", "abir@yahoo.com"]  # 3
user_age = [22, 20]  # 2

list(zip(user_id, user_names, user_mails, user_age)) # zipped result length depends on the smallest collection

for idx, name, email, age in zip(user_id, user_names, user_mails, user_age):
    print(idx, name, email, age)
# Out:
# 001 Alvi alvi@mail.com 22
# 002 Sadia sadia@gmail.com 20

# %%
## Mini Problem: Per Product price + Total price calculation

products = ["Rice", "Salt", "Sugar"]
quantity = [100, 80, 50]
price_list = [60.5, 30.5, 40.0]

total = 0

for item, qty, price in zip(products, quantity, price_list):
    print(f"Item: {item}, Cost: {qty*price}")
    total = total + qty*price

print(f"Total Cost: {total}")
# Out:
# Item: Rice, Cost: 6050.0
# Item: Salt, Cost: 2440.0
# Item: Sugar, Cost: 2000.0
# Total Cost: 10490.0

# %%
user={}
user['Abir'] = {
    "Alvi": {"city": "Dhaka",  "age": 17, "phone": 217457},
    "Sadia": {"city": "New York", "age": 22, "phone": 12763},
    "Samia": {"city": "Rajshahi", "age": 14, "phone": 169463},
    "Jahid": {"city": "London", "age": 20, "phone": 76435},
    "Hasan": {"city": "Istambl", "age": 23, "phone": 76435},
   }

user['Samson'] = {
    "Alex": {"city": "Dhaka",  "age": 17, "phone": 217457},
    "Sadman": {"city": "New York", "age": 22, "phone": 12763},
    "Samuel": {"city": "Rajshahi", "age": 14, "phone": 169463},
    "Jason": {"city": "London", "age": 20, "phone": 76435},
    "Hensen": {"city": "Istambl", "age": 23, "phone": 76435},
   }


search_name=input("Enter the name: ").title()
if search_name in user:
    #user_data=user[search_name]
    #print(user[search_name])
    print("Already exits")
else:
    print("No")
# Out:
# Already exits

# %%
user['Abir']['Alvi']
# Out:
# {'city': 'Dhaka', 'age': 17, 'phone': 217457}
